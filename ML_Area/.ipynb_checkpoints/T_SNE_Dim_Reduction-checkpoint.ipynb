# %% [markdown]
# ---
# title:  "T-SNE using python"
# excerpt: "python t-sne 차원감소"
#
# categories:
#   - Machine-Learning
# tags:
#   - Clustering
#   - Dimension_Reduction
#   - 차원감소
#   - A Medium
# last_modified_at: 2020-05-03T21:15:00-05:00
# ---

# %%
import numpy as np
from scipy.spatial.distance import pdist
from sklearn.manifold.t_sne import _joint_probabilities
from scipy import linalg
from sklearn.metrics import pairwise_distances
from scipy.spatial.distance import squareform
from sklearn.manifold import TSNE
from matplotlib import pyplot as plt
import seaborn as sns
sns.set(rc={'figure.figsize':(11.7,8.27)})
palette = sns.color_palette("bright", 10)

# %% [markdown]
# 이번 posting은 (https://towardsdatascience.com/t-sne-python-example-1ded9953f26) 을 참조했다.
# python 에서는 하기에 대해서, 친절하게도, 데이터를 제공해준다.

# %% [markdown]
# ## sample dataset 불러오기

# %%
from sklearn.datasets import load_digits

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
## If True, returns (data, target) instead of a Bunch object. default=False
X, y = load_digits(return_X_y=True)

# %%
print(X.shape,y.shape)
print("X:type {}, y:type {}".format(type(X),type(y)))
# Out:
# (1797, 64) (1797,)
# X:type <class 'numpy.ndarray'>, y:type <class 'numpy.ndarray'>

# %% [markdown]
# ## t-sne 수학적으로 직접 날코딩하기

# %% [markdown]
# ### 필요한 파라미터 설정

# %%
MACHINE_EPSILON = np.finfo(np.double).eps # smallset postive number. this is not zero. it's very sligtly bigger than 0 
n_components = 2 ## 2차원으로 또는 3차원으로 시각화할때, 어떤 것으로 할지 고르는 것
perplexity = 30

# %%
MACHINE_EPSILON
# Out:
# 2.220446049250313e-16

# %% [markdown]
# ### fit 함수 정의하기

# %%
def fit(X):
    n_samples = X.shape[0]
    
    # Compute euclidean distance
    distances = pairwise_distances(X, metric='euclidean', squared=True) ## sklearn.metrics 에서 제공하는 vector의 distance 구하기
    
#     # Compute joint probabilities p_ij from distances.
#     P = _joint_probabilities(distances=distances, desired_perplexity=perplexity, verbose=False)
    
#     # The embedding is initialized with iid samples from Gaussians with standard deviation 1e-4.
#     X_embedded = 1e-4 * np.random.mtrand._rand.randn(n_samples, n_components).astype(np.float32)
    
#     # degrees_of_freedom = n_components - 1 comes from
#     # "Learning a Parametric Embedding by Preserving Local Structure"
#     # Laurens van der Maaten, 2009.
#     degrees_of_freedom = max(n_components - 1, 1)
    
#     return _tsne(P, degrees_of_freedom, n_samples, X_embedded=X_embedded)

# %% [markdown]
# ## sckit-learn 의 기본 library 사용하기

# %% [markdown]
# 참조
# - 조대협의 Blog (https://bcho.tistory.com/1210)
# - 공식 라이브러 설명문서 (https://scikit-learn.org/stable/modules/generated/sklearn.manifold.TSNE.html)

# %% [markdown]
# class sklearn.manifold.TSNE(n_components=2, perplexity=30.0, early_exaggeration=12.0, learning_rate=200.0, n_iter=1000, n_iter_without_progress=300, min_grad_norm=1e-07, metric='euclidean', init='random', verbose=0, random_state=None, method='barnes_hut', angle=0.5, n_jobs=None)[source]

# %%
tsne = TSNE()
X_embedded = tsne.fit_transform(X)

# %%
print(X.shape)
print(X_embedded.shape)
# Out:
# (1797, 64)
# (1797, 2)

# %%
sns.scatterplot(X_embedded[:,0], X_embedded[:,1], hue=y, legend='full', palette=palette)
